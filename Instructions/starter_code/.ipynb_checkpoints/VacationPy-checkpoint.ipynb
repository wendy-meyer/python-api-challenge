# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
#import gmaps.datasets


# Import API key
from api_keys import g_key

# Access maps with unique API key
gmaps.configure(api_key=g_key)

# %%
#jupyter nbextension enable --py gmaps

# %%
g_key
# Out:
# 'AIzaSyC6FtyVyK0RgIdLPONDAZ-7P5XSYknXDvw'

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# Read our Data file with the pandas library
file = "output_data/cities.csv"
df = pd.read_csv(file)
df
# Out:
#                   City  Cloudiness Country        Date  Humidity    Lat  \
# 0                  eyl          86      SO  1584399079        78   7.98
# 1                vaini          75      TO  1584398911        79 -21.20
# 2              iqaluit          90      CA  1584399079        77  63.75
# 3              rikitea          56      PF  1584399079        79 -23.12
# 4              babakan          61      ID  1584399079        77  -7.28
# ..                 ...         ...     ...         ...       ...    ...
# 559  presidente medici          96      BR  1584399167        90 -11.18
# 560            waipawa         100      NZ  1584399168        76 -41.41
# 561              jizan          20      SA  1584399168        74  17.33
# 562               kaka           1      TM  1584399168        61  37.35
# 563       spanish town          20      JM  1584399168        48  17.99
#
#         Lng  Max Temp  Wind Speed
# 0     49.82     79.41       15.77
# ...

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#lat = df["Lat"]
#lng = df["Lng"]
#coordinates = list(zip(lat, lng))
locations = df[["Lat","Lng"]]
weights = df["Humidity"]
# Customize the size of the figure
#figure_layout = {
 #   'width': '400px',
  #  'height': '300px',
   # 'border': '1px solid black',
    #'padding': '1px',
    #'margin': '0 auto 0 auto'
#}
#fig = gmaps.figure(layout=figure_layout



fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
print(locations)
# Out:
#        Lat     Lng
# 0     7.98   49.82
# 1   -21.20 -175.20
# 2    63.75  -68.51
# 3   -23.12 -134.97
# 4    -7.28  107.22
# ..     ...     ...
# 559 -11.18  -61.90
# 560 -41.41  175.52
# 561  17.33   42.67
# 562  37.35   59.61
# 563  17.99  -76.96
#
# [564 rows x 2 columns]

# %%
print(weights)
# Out:
# 0      78
# 1      79
# 2      77
# 3      79
# 4      77
#        ..
# 559    90
# 560    76
# 561    74
# 562    61
# 563    48
# Name: Humidity, Length: 564, dtype: int64

# %%
#jupyter nbextension enable --py --sys-prefix widgetsnbextension

# %%
#jupyter nbextension list

# %%
#A max temperature lower than 80 degrees but higher than 70.

#Wind speed less than 10 mph.

#Zero cloudiness.

#Drop any rows that don't contain all three conditions. 
#You want to be sure the weather is ideal.

#Note: Feel free to adjust to your specifications 
#but be sure to limit the number of rows returned 
#by your API requests to a reasonable number.

# %%
df
# Out:
#                   City  Cloudiness Country        Date  Humidity    Lat  \
# 0                  eyl          86      SO  1584399079        78   7.98
# 1                vaini          75      TO  1584398911        79 -21.20
# 2              iqaluit          90      CA  1584399079        77  63.75
# 3              rikitea          56      PF  1584399079        79 -23.12
# 4              babakan          61      ID  1584399079        77  -7.28
# ..                 ...         ...     ...         ...       ...    ...
# 559  presidente medici          96      BR  1584399167        90 -11.18
# 560            waipawa         100      NZ  1584399168        76 -41.41
# 561              jizan          20      SA  1584399168        74  17.33
# 562               kaka           1      TM  1584399168        61  37.35
# 563       spanish town          20      JM  1584399168        48  17.99
#
#         Lng  Max Temp  Wind Speed
# 0     49.82     79.41       15.77
# ...

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
narrowed_city_df = df.loc[(df["Max Temp"]<80)&(df["Max Temp"]>70)\
                         &(df["Cloudiness"]==0)].dropna()
#narrowed_city_df = narrowed_city_df.loc[(df["Max Temp"]>70)]
#narrowed_city_df = narrowed_city_df.loc[(df["Cloudiness"]==0)]
#narrowed_city_df = narrowed_city_df.loc[(df["Max Temp"]>70)]
#narrowed_city_df.dropna()
narrowed_city_df
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 98      port hedland           0      AU  1584399095        88 -20.32  118.57
# 199  arraial do cabo           0      BR  1584398917        86 -22.97  -42.03
# 263   nueve de julio           0      AR  1584399121        59 -35.44  -60.88
# 310        abu dhabi           0      AE  1584399046        73  24.47   54.37
# 421        ratnagiri           0      IN  1584398923        57  16.98   73.30
# 430         yaguajay           0      CU  1584399147        77  22.33  -79.24
# 436         saldanha           0      ZA  1584399148        46 -33.01   17.94
# 466         san juan           0      AR  1584399115        51 -31.54  -68.54
# 469           dingle           0      PH  1584399153        74  11.00  122.67
# 475        kununurra           0      AU  1584399154        94 -15.77  128.73
# 515             buin           0      CL  1584399160        36 -33.73  -70.75
# ...

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = narrowed_city_df.copy()
hotel_df["Hotel Name"] = ""

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = { 
    "rankby": "distance",
    "type": "lodging",
    "key": g_key,
}
# use iterrows to iterate through pandas dataframe
for index, row in hotel_df.iterrows():

    # get hotel location from hotel_df
    lat = row['Lat']
    lng = row["Lng"]
    #city = row["City"]

    # add keyword to params dict
    params['location'] = str(lat)+","+str(lng)

    # assemble url and make API request
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
        hotel_df.loc[index, 'Hotel Name'] = results[0]['name']
        
    except (KeyError, IndexError):  #HELP DO I NEED THIS STEP?
        print("Missing field/result... skipping.")

# %%
smaller_df = hotel_df[["City","Country","Hotel Name","Lat","Lng"]]
smaller_df
# Out:
#                 City Country  \
# 98      port hedland      AU
# 199  arraial do cabo      BR
# 263   nueve de julio      AR
# 310        abu dhabi      AE
# 421        ratnagiri      IN
# 430         yaguajay      CU
# 436         saldanha      ZA
# 466         san juan      AR
# 469           dingle      PH
# 475        kununurra      AU
# 515             buin      CL
# 522        les cayes      HT
#
#                                            Hotel Name    Lat     Lng
# 98                                The Esplanade Hotel -20.32  118.57
# 199                Kitchenette Elaine Arraial do Cabo -22.97  -42.03
# 263                              Avenida Palace Hotel -35.44  -60.88
# 310  Marriott Executive Apartments Downtown Abu Dhabi  24.47   54.37
# 421                                      Bhatye Khadi  16.98   73.30
# 430                        Hostal Idalmis y José Luis  22.33  -79.24
# 436                         Fidel castrol khayelitsha -33.01   17.94
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map



# Display Map
